# %%
import pandas as pd
from datetime import datetime

def parse_date(date_str):
    if pd.isna(date_str) or date_str == 'NaN':
        return None  # Handle missing or NaN values
    try:
        return datetime.strptime(date_str, '%Y-%m-%d')
    except ValueError:
        try:
            return datetime.strptime(date_str, '%m/%d/%Y')
        except ValueError:
            return None  # Handle unrecognized date formats as needed

# %%
# TOTAL YEARS OF EXPERIENCE
# Function to calculate total years of experience
def calculate_years_of_experience(employments):
    total_years = 0
    for employment in employments:
        start_date = parse_date(employment["started_on"])
        end_date = parse_date(employment["ended_on"]) if employment["ended_on"] != "NaN" else datetime.now()
        total_years += (end_date - start_date).days / 365.25
    return total_years

# %%
# AGGREGATE EXPERIENCE
from datetime import datetime, timedelta

def create_aggregate_experience(employments):
    total_years = 0
    total_revenue = 0
    for employment in employments:
        start_date = parse_date(employment["started_on"])
        if start_date is None:
            continue  # Skip this employment record if start_date is None
        
        end_date_str = employment["ended_on"]
        if end_date_str != "NaN":
            end_date = parse_date(end_date_str)
            if end_date is None:
                end_date = datetime.now()  # Use current date as end date if parsing fails
        else:
            end_date = datetime.now()  # Use current date as end date if "NaN"
        
        # Calculate years of experience
        if end_date > start_date:
            total_years += (end_date - start_date).days / 365.25
        
        # Accumulate revenue
        total_revenue += employment.get("company_revenue_amount_usd", 0)
    
    # Calculate average revenue
    average_revenue = total_revenue / len(employments) if employments else 0
    
    return total_years, average_revenue

# %%
# EDUCATIONAL SUMMARY 
def generate_education_summary(educations, name):
    if not isinstance(educations, list):
        return f"{name} has no recorded education history."

    if not educations:
        return f"{name} has no recorded education history."

    education_summaries = []
    for edu in educations:
        institution = edu["institution_name"]
        subject = edu.get("subject")
        degree = edu.get("degree")
        end_date = edu.get("ended_on")
        
        # Check for NaN or unknown values
        if pd.isna(subject) or subject == "NaN":
            continue
        if pd.isna(degree) or degree == "NaN":
            continue
        if pd.isna(end_date) or end_date == "NaN":
            continue
        
        # ended_on = edu.get("ended_on", "unknown graduation date")
        education_summary = f"{name} studied {subject} at {institution} and graduated in {end_date}."
        education_summaries.append(education_summary)

    return " ".join(education_summaries)

# %%
# EMPLOYMENT SUMMARY 
def generate_employment_summary(employments, name):
    if not employments:
        return f"{name} has no recorded work experience."

    employment_summaries = []
    for emp in employments:
        seniority = emp["seniority_level"]
        if pd.isna(seniority) or seniority == "NaN":
            continue

        started = "is currently working" if emp["ended_on"] == "NaN" else "has worked"
        if pd.isna(started) or started == "NaN":
            continue
        
        company_name = emp["company_name"]
        if pd.isna(company_name) or company_name == "NaN":
            continue

        headcount = emp.get("company_headcount")
        # Check for NaN or unknown values
        if pd.isna(headcount) or headcount == "NaN":
            continue

        # Handle revenue formatting
        revenue = emp.get("company_revenue_amount_usd")
        # Check for NaN or unknown values
        if pd.isna(revenue) or revenue == "NaN":
            continue
        if isinstance(revenue, str):
            try:
                revenue = float(revenue)
                revenue = f"{revenue:,.2f}"
            except ValueError:
                revenue = "unknown"
        elif isinstance(revenue, (int, float)):
            revenue = f"{revenue:,.2f}"

        # description = emp.get("position_description", "Unknown")

        summary = (f"{name} {started} as a {seniority} {emp['title']} at {company_name}, "
                   f" with {headcount} employees and "
                   f"a revenue of ${revenue}. "
                #    f"In this role, {name} was skilled in {description}. "
        )
        employment_summaries.append(summary)

    return " ".join(employment_summaries)

# %%
def generate_aggregate_summary(employments, name):
    if not isinstance(employments, list):
        return f"{name} has no recorded employment history."

    if not employments:
        return f"{name} has no recorded employment history."

    total_years, average_revenue = create_aggregate_experience(employments)
    job_titles = []
    companies = []

    for emp in employments:
        title = emp.get("title")
        company_name = emp.get("company_name")

        # Check for NaN or unknown values
        if pd.isna(title) or title == "NaN":
            continue
        if pd.isna(company_name) or company_name == "NaN":
            continue

        job_titles.append(title)
        companies.append(company_name)

    if not job_titles or not companies:
        return f"{name} has no valid recorded employment history."

    summary = (f"{name} has over {total_years:.1f} years of experience "
               f"across the following job titles: {', '.join(job_titles)} at companies: {', '.join(companies)} "
               f"with an average revenue size of ${average_revenue:,.2f}.")

    return summary

# %%
def generate_summary_content(record):
    name = record["name"]
    employments = record.get("employments", [])
    educations = record.get("education", [])
    

    employment_summary = generate_employment_summary(employments, name) if employments else None
    education_summary = generate_education_summary(educations, name) if educations else None
    aggregate_summary = generate_aggregate_summary(employments, name) if employments else None

    return {
        "employment_summary": employment_summary,
        "education_summary": education_summary,
        "aggregate_summary": aggregate_summary
    }

# %%
import re

# %%
# Sanitize file name by removing or replacing invalid characters
def sanitize_filename(filename):
    return re.sub(r'[\/:*?"<>|]', '_', filename)

# %%
import os  # Import the os module for file operations

# METHOD TO GENERATE THE PERSONS AGGREGATE, EDUCATIONAL AND EMPLOYMENT SUMMARY PARAGRAPH 
def main():
    # Load JSON data into a pandas DataFrame
    df = pd.read_json('input_people_data_02.json', lines=True)

    # Create a directory to store output files (if it doesn't exist)
    output_directory = 'output_files'
    os.makedirs(output_directory, exist_ok=True)

    # Iterate over each row in the DataFrame
    for index, row in df.iterrows():
        record = row.to_dict()
        summary_content = generate_summary_content(record)

        # Generate the file name based on the person's name and ID
        person_id = record["person_id"]
        name = record["name"].replace(" ", "_")
        sanitized_name = sanitize_filename(name)
        output_txt_file = os.path.join(output_directory, f'output_summary_{person_id}_{sanitized_name}.txt')

        # Save to individual TXT files
        with open(output_txt_file, 'w', encoding='utf-8') as file:
            employment_summary = summary_content.get('employment_summary')
            education_summary = summary_content.get('education_summary')
            aggregate_summary = summary_content.get('aggregate_summary')

            # Format each section as a full paragraph, skipping if None
            combined_summary = ""
            if employment_summary:
                combined_summary += "Employment Summary:\n" + employment_summary + "\n"
            if education_summary:
                combined_summary += "Education Summary:\n" + education_summary + "\n"
            if aggregate_summary:
                combined_summary += "Aggregate Summary:\n" + aggregate_summary + "\n"
            combined_summary += "-"*200 + "\n\n"

            file.write(combined_summary)

        print(f"Generated text summary saved to {output_txt_file}")

if __name__ == "__main__":
    main()
# Out:
# Generated text summary saved to output_files\output_summary_949256266_Vivian_Weng.txt
# Generated text summary saved to output_files\output_summary_902184389_Hendrik_Bourgeois.txt
# Generated text summary saved to output_files\output_summary_48171849_Courtney_Turner.txt
# Generated text summary saved to output_files\output_summary_74707094_Katie_Richter.txt
# Generated text summary saved to output_files\output_summary_1042153985_Victor_Merced-Felix.txt
# Generated text summary saved to output_files\output_summary_787025923_Lynda_Zhang.txt
# Generated text summary saved to output_files\output_summary_715859477_Tamara_Vranjes.txt
# Generated text summary saved to output_files\output_summary_51432999_Juan_Sanchez.txt
# Generated text summary saved to output_files\output_summary_71726687_Katherine_Hicks.txt
# Generated text summary saved to output_files\output_summary_909645082_Lucas_Turrado.txt
# Generated text summary saved to output_files\output_summary_20891932_Cynthia_Collins.txt
# Generated text summary saved to output_files\output_summary_123861635_Luke_Meyer.txt
# Generated text summary saved to output_files\output_summary_124440405_Ashton_Mitchell_Dixon.txt
# Generated text summary saved to output_files\output_summary_22355698_Ritchie_Lozada.txt
# Generated text summary saved to output_files\output_summary_734368_Abby_Anderson_Edling.txt
# Generated text summary saved to output_files\output_summary_952242351_Emily_Nguyen.txt
# Generated text summary saved to output_files\output_summary_22216310_Mark_Gotuaco.txt
# Generated text summary saved to output_files\output_summary_161786823_Evan_Li.txt
# Generated text summary saved to output_files\output_summary_1169460415_Terrell_Thomas.txt
# Generated text summary saved to output_files\output_summary_837503042_Clara_Têtu.txt
# Generated text summary saved to output_files\output_summary_942851003_Cordelia_Price.txt
# Generated text summary saved to output_files\output_summary_1058792153_Carlos_Nogueira.txt
# Generated text summary saved to output_files\output_summary_122947714_Ethan_Pitts.txt
# Generated text summary saved to output_files\output_summary_789056453_Federico_Maggiani.txt
# Generated text summary saved to output_files\output_summary_94178805_Pablo_Meyer.txt
# Generated text summary saved to output_files\output_summary_96276184_Julie_Smith.txt
# Generated text summary saved to output_files\output_summary_54233909_Lily_Dorsey.txt
# Generated text summary saved to output_files\output_summary_89758789_Mike_Mcaleer.txt
# Generated text summary saved to output_files\output_summary_770222155_Juan_Ayoso.txt
# Generated text summary saved to output_files\output_summary_74469361_Dean_Kruse.txt
# Generated text summary saved to output_files\output_summary_16135235_Jordan_Redstone.txt
# Generated text summary saved to output_files\output_summary_20916348_David_Kilzer.txt
# Generated text summary saved to output_files\output_summary_57288072_Anthony_Salvaggio.txt
# Generated text summary saved to output_files\output_summary_60063650_Javier_Martinez.txt
# Generated text summary saved to output_files\output_summary_76851737_Erin_Parker.txt
# Generated text summary saved to output_files\output_summary_30003849_Liz_Meredith,_EdD.txt
# Generated text summary saved to output_files\output_summary_960796091_Jacob_Mksyartinian.txt
# Generated text summary saved to output_files\output_summary_1117572862_Jack_Breese.txt
# Generated text summary saved to output_files\output_summary_693540132_Lika_Razac-Ince.txt
# Generated text summary saved to output_files\output_summary_1017713620_Sarina_Studer.txt
# Generated text summary saved to output_files\output_summary_936754239_Hilaire_McDonald.txt
# Generated text summary saved to output_files\output_summary_37933678_Robert_Megill.txt
# Generated text summary saved to output_files\output_summary_22640178_Shannon_Sinunu.txt
# Generated text summary saved to output_files\output_summary_74982341_Melissa_Clearwater.txt
# Generated text summary saved to output_files\output_summary_22973607_Vinay_Subramanian.txt
# Generated text summary saved to output_files\output_summary_856482513_Karl_Dubost.txt
# Generated text summary saved to output_files\output_summary_93367049_Ray_V..txt
# Generated text summary saved to output_files\output_summary_118418234_Kenny_Sheridan.txt
# Generated text summary saved to output_files\output_summary_1044260885_Micayla_Chow.txt
# Generated text summary saved to output_files\output_summary_705049829_Dave_Wisniewski.txt
# Generated text summary saved to output_files\output_summary_1010245103_Jose_Antonio_Mustienes_Ferrer.txt
# Generated text summary saved to output_files\output_summary_74666514_Joseph_Cramer.txt
# Generated text summary saved to output_files\output_summary_64876372_David_Coyle.txt
# Generated text summary saved to output_files\output_summary_741629676_Iason_Bakogiannis.txt
# Generated text summary saved to output_files\output_summary_1040718272_Christopher_Bremser.txt
# Generated text summary saved to output_files\output_summary_708025988_Jean_Laknut.txt
# Generated text summary saved to output_files\output_summary_741189402_Zuhair_Al-Scharif.txt
# Generated text summary saved to output_files\output_summary_89139296_Nik_Hensey.txt
# Generated text summary saved to output_files\output_summary_24679216_Edward_Blanck.txt
# Generated text summary saved to output_files\output_summary_22864801_Www.Linkedin.Com_Armstrong.txt
# Generated text summary saved to output_files\output_summary_27131879_Michelle_Hanson.txt
# Generated text summary saved to output_files\output_summary_19268739_Lauren_Bumatay.txt
# Generated text summary saved to output_files\output_summary_773874_Viresh_Ramdatmisier.txt
# Generated text summary saved to output_files\output_summary_86953298_Mark_Smith.txt
# Generated text summary saved to output_files\output_summary_103025237_Christina_Gabsa.txt
# Generated text summary saved to output_files\output_summary_21935754_Manoj_Pillai.txt
# Generated text summary saved to output_files\output_summary_45253266_Michael_Klein.txt
# Generated text summary saved to output_files\output_summary_1072269177_Van_Tan.txt
# Generated text summary saved to output_files\output_summary_16028852_Felipe_Freitas.txt
# Generated text summary saved to output_files\output_summary_990279375_Jakob_Peterhänsel.txt
# Generated text summary saved to output_files\output_summary_25338641_Joseph_Lisa.txt
# Generated text summary saved to output_files\output_summary_747062710_Michael_Huang.txt
# Generated text summary saved to output_files\output_summary_21360363_Jason_Lemiere.txt
# Generated text summary saved to output_files\output_summary_75073132_Paul_Anderson.txt
# Generated text summary saved to output_files\output_summary_67121188_Gurpreet_Singh.txt
# Generated text summary saved to output_files\output_summary_65673618_Emily_Parker.txt
# Generated text summary saved to output_files\output_summary_728055594_Shaykhah_Almalik.txt
# Generated text summary saved to output_files\output_summary_718242022_Debbie_Drummond.txt
# Generated text summary saved to output_files\output_summary_124628628_Stephanie_X.txt
# Generated text summary saved to output_files\output_summary_122883279_Matt_Aldo.txt
# Generated text summary saved to output_files\output_summary_956740744_Cara_Hope.txt
# Generated text summary saved to output_files\output_summary_982127478_Xinwen_Ni.txt
# Generated text summary saved to output_files\output_summary_85250785_Rosann_Cavallaro.txt
# Generated text summary saved to output_files\output_summary_767050889_Robert_O._Akander-Lima.txt
# Generated text summary saved to output_files\output_summary_937425828_Amund_Noonan.txt
# Generated text summary saved to output_files\output_summary_993985187_Eddie_McGrory.txt
# Generated text summary saved to output_files\output_summary_52762066_Kevin_L._Fowler.txt
# Generated text summary saved to output_files\output_summary_22520336_Ben_Stott.txt
# Generated text summary saved to output_files\output_summary_23766587_Brendon_Tago.txt
# Generated text summary saved to output_files\output_summary_19996701_Mike_Crowe.txt
# Generated text summary saved to output_files\output_summary_16049707_Yifan_Ge.txt
# Generated text summary saved to output_files\output_summary_917044821_刘柠.txt
# Generated text summary saved to output_files\output_summary_1082448371_Quinn_Cale.txt
# Generated text summary saved to output_files\output_summary_26470145_Lisa_Helms.txt
# Generated text summary saved to output_files\output_summary_745971556_thomas_gurney.txt
# Generated text summary saved to output_files\output_summary_124021464_Wawa_Field.txt
# Generated text summary saved to output_files\output_summary_92297837_Gisela_Santiago-Lopez.txt
# Generated text summary saved to output_files\output_summary_953974165_Kadir_Ağırtmış.txt
# Generated text summary saved to output_files\output_summary_20316412_Alli_Inouye.txt
# Generated text summary saved to output_files\output_summary_16234426_Matt_Klein,_Ph.D..txt
# Generated text summary saved to output_files\output_summary_994637657_Annie_Cai.txt
# Generated text summary saved to output_files\output_summary_1114046133_Chris_Wang.txt
# Generated text summary saved to output_files\output_summary_1042055636_Megan_Ostermiller.txt
# Generated text summary saved to output_files\output_summary_932339345_Lachlan_Jacobson.txt
# Generated text summary saved to output_files\output_summary_67952049_Dan_Marquardt.txt
# Generated text summary saved to output_files\output_summary_87998964_Cesar_Honores.txt
# Generated text summary saved to output_files\output_summary_124612718_Brinda_Pullen.txt
# Generated text summary saved to output_files\output_summary_25635764_Jhamal_Robinson.txt
# Generated text summary saved to output_files\output_summary_883914181_Vathulen_Raveenderan.txt
# Generated text summary saved to output_files\output_summary_993308913_Francesco_Squatrito.txt
# Generated text summary saved to output_files\output_summary_123113070_Lee_Osaki.txt
# Generated text summary saved to output_files\output_summary_778561577_Adam_Smythe.txt
# Generated text summary saved to output_files\output_summary_26286540_Kimberly_Cooper.txt
# Generated text summary saved to output_files\output_summary_122853548_Jesse_Emken.txt
# Generated text summary saved to output_files\output_summary_776194699_Mariam_Abu_hajeer.txt
# Generated text summary saved to output_files\output_summary_67766181_Aaron_Hunter.txt
# Generated text summary saved to output_files\output_summary_859525920_Matteo_Vianoli.txt
# Generated text summary saved to output_files\output_summary_22831749_Venkatesh_Pandit.txt
# Generated text summary saved to output_files\output_summary_1099324_Vince_Guel.txt
# Generated text summary saved to output_files\output_summary_21535235_Jessica_Lin.txt
# Generated text summary saved to output_files\output_summary_1567835_Rick_Mccarthy.txt
# Generated text summary saved to output_files\output_summary_1157318885_Art_Burov.txt
# Generated text summary saved to output_files\output_summary_368727_William_Bencze.txt
# Generated text summary saved to output_files\output_summary_28729993_Zora_Wolter.txt
# Generated text summary saved to output_files\output_summary_114036636_Daniel_Charness.txt
# Generated text summary saved to output_files\output_summary_990939356_Stefania_Baldi.txt
# Generated text summary saved to output_files\output_summary_21526185_John_Spurling.txt
# Generated text summary saved to output_files\output_summary_932586294_Alan_Godoy.txt
# Generated text summary saved to output_files\output_summary_21928496_Kent_Ryhorchuk.txt
# Generated text summary saved to output_files\output_summary_21045865_Eklavya_Singh.txt
# Generated text summary saved to output_files\output_summary_727755725_Oris_Lima.txt
# Generated text summary saved to output_files\output_summary_726050197_江城丞.txt
# Generated text summary saved to output_files\output_summary_675418_Emily_Lanfear.txt
# Generated text summary saved to output_files\output_summary_107106270_Eli_Wimberley.txt
# Generated text summary saved to output_files\output_summary_87662689_Zachary_Whitney.txt
# Generated text summary saved to output_files\output_summary_87622862_Tyler_Bang.txt
# Generated text summary saved to output_files\output_summary_122729439_Jeremiah_Rosales.txt
# Generated text summary saved to output_files\output_summary_104276148_Kathleen_Reen.txt
# Generated text summary saved to output_files\output_summary_26072794_Katelyn_Fitzgerald.txt
# Generated text summary saved to output_files\output_summary_791770486_Amanda_Soh.txt
# Generated text summary saved to output_files\output_summary_891209834_Jhorman_Bueni.txt
# Generated text summary saved to output_files\output_summary_21043029_Dickson_Seow.txt
# Generated text summary saved to output_files\output_summary_22102229_Michael_Miller.txt
# Generated text summary saved to output_files\output_summary_717766708_Inês_Garcia.txt
# Generated text summary saved to output_files\output_summary_64332405_Rebecca_Hunter.txt
# Generated text summary saved to output_files\output_summary_1421522_Maria_Kavaliova.txt
# Generated text summary saved to output_files\output_summary_866965268_Gurpreet_(Gary)_Takhar.txt
# Generated text summary saved to output_files\output_summary_16306532_Nitin_Singhal.txt
# Generated text summary saved to output_files\output_summary_14741305_Ali_Ozhan.txt
# Generated text summary saved to output_files\output_summary_66712887_Scott_Flinn.txt
# Generated text summary saved to output_files\output_summary_22877631_Tara_Lucier.txt
# Generated text summary saved to output_files\output_summary_773135001_Omid_Moeini.txt
# Generated text summary saved to output_files\output_summary_21644396_Katie_Boord.txt
# Generated text summary saved to output_files\output_summary_14271088_Kris_Wilson.txt
# Generated text summary saved to output_files\output_summary_22498270_Suzie_Buxton.txt
# Generated text summary saved to output_files\output_summary_20871223_Darrell_Eng.txt
# Generated text summary saved to output_files\output_summary_140100873_Ndiaga_Cisse.txt
# Generated text summary saved to output_files\output_summary_92716712_Kate_Elliott.txt
# Generated text summary saved to output_files\output_summary_88613394_Jiajun_Law.txt
# Generated text summary saved to output_files\output_summary_925367406_Saeed_Battu.txt
# Generated text summary saved to output_files\output_summary_20571239_Brad_DeBattista.txt
# Generated text summary saved to output_files\output_summary_21121938_Geoff_Fedoroff.txt
# Generated text summary saved to output_files\output_summary_896786050_Nicolas_Martin.txt
# Generated text summary saved to output_files\output_summary_122369848_Chris_Sullivan.txt
# Generated text summary saved to output_files\output_summary_1112996877_angel_E..txt
# Generated text summary saved to output_files\output_summary_630454_Candi_Castleberry_Singleton.txt
# Generated text summary saved to output_files\output_summary_1316856_Leon_Long.txt
# Generated text summary saved to output_files\output_summary_115600981_Barkeem_Blackwell.txt
# Generated text summary saved to output_files\output_summary_123918498_Aleksandar_Dekic.txt
# Generated text summary saved to output_files\output_summary_876117187_Hector_Guilarte.txt
# Generated text summary saved to output_files\output_summary_24752989_Elliott_Lemberger.txt
# Generated text summary saved to output_files\output_summary_123763993_Austin_Portinause.txt
# Generated text summary saved to output_files\output_summary_21160144_Allen_Hughes.txt
# Generated text summary saved to output_files\output_summary_122900496_Luis_Eduardo_Huerta_Ramirez.txt
# Generated text summary saved to output_files\output_summary_13755660_Francisco_Gonzalez.txt
# Generated text summary saved to output_files\output_summary_901852123_Zlatica_Brajovic.txt
# Generated text summary saved to output_files\output_summary_21688670_Jianhang_(James)_Gao.txt
# Generated text summary saved to output_files\output_summary_70901779_Lynn_Dugger.txt
# Generated text summary saved to output_files\output_summary_754822809_Arthur_Lin.txt
# Generated text summary saved to output_files\output_summary_67382103_Matthew_Perry.txt
# Generated text summary saved to output_files\output_summary_161894027_Sandra_Ajimotokin.txt
# Generated text summary saved to output_files\output_summary_124549754_Yashodhan_Patil.txt
# Generated text summary saved to output_files\output_summary_78973849_Brett_Francisco.txt
# Generated text summary saved to output_files\output_summary_121266494_Cristina_A..txt
# Generated text summary saved to output_files\output_summary_937296631_Mert_Woodard.txt
# Generated text summary saved to output_files\output_summary_881200242_Julia_White.txt
# Generated text summary saved to output_files\output_summary_1083288242_Audrey_Bullock.txt
# Generated text summary saved to output_files\output_summary_128245758_willie_charles_moore.txt
# Generated text summary saved to output_files\output_summary_1001418993_Fahd_Bourara.txt
# Generated text summary saved to output_files\output_summary_1235856_AL_Hoy.txt
# Generated text summary saved to output_files\output_summary_123956470_Kerrick_Rhone.txt
# Generated text summary saved to output_files\output_summary_20017610_Ming-Du_Kang.txt
# Generated text summary saved to output_files\output_summary_815825947_François_Lesage.txt
# Generated text summary saved to output_files\output_summary_122929449_Kevin_Mistry.txt
# Generated text summary saved to output_files\output_summary_252910_Makoto_Inada.txt
# Generated text summary saved to output_files\output_summary_321427_Andy_Piper.txt
# Generated text summary saved to output_files\output_summary_1009772362_Kishan_kumar.txt
# Generated text summary saved to output_files\output_summary_734526393_Igor_Antarov.txt
# Generated text summary saved to output_files\output_summary_17831711_Joey_Berg.txt
# Generated text summary saved to output_files\output_summary_21035868_Drew_Harmon.txt
# Generated text summary saved to output_files\output_summary_818760538_Jorge_Milburn.txt
# Generated text summary saved to output_files\output_summary_763279854_Salah_Alhomoud.txt
# Generated text summary saved to output_files\output_summary_914716343_Amy_Kiernan.txt
# Generated text summary saved to output_files\output_summary_21179453_Robert_Forloine.txt
# Generated text summary saved to output_files\output_summary_954367214_Milan_Trimborn.txt
# Generated text summary saved to output_files\output_summary_20128134_Nikhil_Kumar.txt
# Generated text summary saved to output_files\output_summary_25137746_Jessica_Weeks.txt
# Generated text summary saved to output_files\output_summary_21475964_James_Debrock.txt
# Generated text summary saved to output_files\output_summary_16358651_Nate_Veldkamp.txt
# Generated text summary saved to output_files\output_summary_1072261_Daniel_Thompson.txt
# Generated text summary saved to output_files\output_summary_935387623_Ahmed_Osama,_MBA.txt
# Generated text summary saved to output_files\output_summary_93800062_Wifredo__Wifi__Fernandez.txt
# Generated text summary saved to output_files\output_summary_1125932468_V_D.txt
# Generated text summary saved to output_files\output_summary_16268112_Miriam_Sedman.txt
# Generated text summary saved to output_files\output_summary_116559984_Lisa_Appelbaum.txt
# Generated text summary saved to output_files\output_summary_22059144_Matt_Langshur.txt
# Generated text summary saved to output_files\output_summary_1115857277_Jennifer_B..txt
# Generated text summary saved to output_files\output_summary_122887507_Kellan_Jaduram.txt
# Generated text summary saved to output_files\output_summary_882216298_Omar_Schoijet.txt
# Generated text summary saved to output_files\output_summary_1021429160_Isaac_López.txt
# Generated text summary saved to output_files\output_summary_16281102_Mortada_Mehyar.txt
# Generated text summary saved to output_files\output_summary_785329995_Sam_Waymont.txt
# Generated text summary saved to output_files\output_summary_1106531865_Yaojie_Xiong.txt
# Generated text summary saved to output_files\output_summary_793119_Nadine_Sequeira_Sham.txt
# Generated text summary saved to output_files\output_summary_122117064_Sanju_Varma.txt
# Generated text summary saved to output_files\output_summary_122395299_Josh_Emley.txt
# Generated text summary saved to output_files\output_summary_107007678_Gae_Goodwin.txt
# Generated text summary saved to output_files\output_summary_45299979_William_Gregory.txt
# Generated text summary saved to output_files\output_summary_1088505541_Carolyn_J_Levine.txt
# Generated text summary saved to output_files\output_summary_1040517193_Hoang_Cao.txt
# Generated text summary saved to output_files\output_summary_20927269_Danielle_Douthett.txt
# Generated text summary saved to output_files\output_summary_110423247_Michael_Myers.txt
# Generated text summary saved to output_files\output_summary_93425607_Abhinav_Ramesh.txt
# Generated text summary saved to output_files\output_summary_1411727_Kelsey_Belmonte.txt
# Generated text summary saved to output_files\output_summary_735504925_Seonghwan_Jeon.txt
# Generated text summary saved to output_files\output_summary_104639145_Lexi_Neaman.txt
# Generated text summary saved to output_files\output_summary_19804860_Prashanth_Menon.txt
# Generated text summary saved to output_files\output_summary_75126202_Rodrigo_Urrutia.txt
# Generated text summary saved to output_files\output_summary_22003169_Lindsey_Jubel.txt
# Generated text summary saved to output_files\output_summary_28250746_Stephen_Critchlow.txt
# Generated text summary saved to output_files\output_summary_80744720_Garry_Anderson.txt
# Generated text summary saved to output_files\output_summary_1040887627_Andy_Estrada.txt
# Generated text summary saved to output_files\output_summary_20494258_Alexander_Perez.txt
# Generated text summary saved to output_files\output_summary_122146926_Alexander_Jack_Dominic.txt
# Generated text summary saved to output_files\output_summary_21628724_Jigyasa_Grover_👩🏻‍💻✨.txt
# Generated text summary saved to output_files\output_summary_748711993_Simon_Brierley.txt
# Generated text summary saved to output_files\output_summary_886950999_John-Michael_Irving.txt
# Generated text summary saved to output_files\output_summary_721984433_Matteo_Carcascio.txt
# Generated text summary saved to output_files\output_summary_1039932213_Rong_Jin.txt
# Generated text summary saved to output_files\output_summary_111374016_Corina_Varlan.txt
# Generated text summary saved to output_files\output_summary_65409846_Tiffany_Bailey_Dalton.txt
# Generated text summary saved to output_files\output_summary_735862184_Mirna_Abousamra.txt
# Generated text summary saved to output_files\output_summary_908611053_Pallavi_Walia.txt
# Generated text summary saved to output_files\output_summary_851374792_zhi_zhang（PMP).txt
# Generated text summary saved to output_files\output_summary_1049090937_Arash_Delijani.txt
# Generated text summary saved to output_files\output_summary_113624277_Christine_Cuoco.txt
# Generated text summary saved to output_files\output_summary_88157593_Lisa_Cohen.txt
# Generated text summary saved to output_files\output_summary_21363890_Holly_Wheeler.txt
# Generated text summary saved to output_files\output_summary_1001097317_Lama_Al_Himssi.txt
# Generated text summary saved to output_files\output_summary_21729317_Kira_Roytburg.txt
# Generated text summary saved to output_files\output_summary_969593208_Mostafa_Elbennawy.txt
# Generated text summary saved to output_files\output_summary_25767010_john_doevin.txt
# Generated text summary saved to output_files\output_summary_21585849_Joe_Thatcher.txt
# Generated text summary saved to output_files\output_summary_65565973_Chris_Ciardi.txt
# Generated text summary saved to output_files\output_summary_574392_Dushyant_Sapre_杜勝.txt
# Generated text summary saved to output_files\output_summary_22412265_Sophie_Maquiling.txt
# Generated text summary saved to output_files\output_summary_123048569_Baofu_Ma.txt
# Generated text summary saved to output_files\output_summary_998725221_Preetha_Athrey.txt
# Generated text summary saved to output_files\output_summary_737912664_Sebastiaan_Van_Leuven.txt
# Generated text summary saved to output_files\output_summary_818525435_Stephen_T..txt
# Generated text summary saved to output_files\output_summary_761195553_Ritu_Pal.txt
# Generated text summary saved to output_files\output_summary_774495396_Eduardo_Arevalo.txt
# Generated text summary saved to output_files\output_summary_74536534_Fred_Thum.txt
# Generated text summary saved to output_files\output_summary_820951_Manuel_Vivoda.txt
# Generated text summary saved to output_files\output_summary_65388113_Zachary_Fox.txt
# Generated text summary saved to output_files\output_summary_74219311_Anu_Palaniswamy.txt
# Generated text summary saved to output_files\output_summary_88491879_Jody_Swartz.txt
# Generated text summary saved to output_files\output_summary_86922817_Melissa_Samudio.txt
# Generated text summary saved to output_files\output_summary_887633117_Ben_Latchford.txt
# Generated text summary saved to output_files\output_summary_71458921_Deanna_Butler.txt
# Generated text summary saved to output_files\output_summary_1007850861_Daniel_Ridge.txt
# Generated text summary saved to output_files\output_summary_895428543_Jess_Baah-Achamfour.txt
# Generated text summary saved to output_files\output_summary_114168825_Adam_Flomenbaum.txt
# Generated text summary saved to output_files\output_summary_65056292_Karl_Beckstein.txt
# Generated text summary saved to output_files\output_summary_21368780_Gilad_Gershoni.txt
# Generated text summary saved to output_files\output_summary_74535750_Firas_Azrai.txt
# Generated text summary saved to output_files\output_summary_763252364_Kevin_Angelo_Molato.txt
# Generated text summary saved to output_files\output_summary_764307372_winnie_leung.txt
# Generated text summary saved to output_files\output_summary_50071863_James_Fitch.txt
# Generated text summary saved to output_files\output_summary_47491080_Connor_McNeil,_CPA.txt
# Generated text summary saved to output_files\output_summary_118252959_Katie_McDonough.txt
# Generated text summary saved to output_files\output_summary_124700273_Kirk_Beitz.txt
# Generated text summary saved to output_files\output_summary_1019024785_Tomás_Fernandes.txt
# Generated text summary saved to output_files\output_summary_1197051_Nanae_Yamagishi.txt
# Generated text summary saved to output_files\output_summary_102336895_Sam_Roller.txt
# Generated text summary saved to output_files\output_summary_76991078_Kristina_Pierce.txt
# Generated text summary saved to output_files\output_summary_838176435_Marco_Ferrara.txt
# Generated text summary saved to output_files\output_summary_834794985_Marcus_Karimifar.txt
# Generated text summary saved to output_files\output_summary_115424673_Dimitri_Pun.txt
# Generated text summary saved to output_files\output_summary_882899139_Dameyon_Bonson.txt
# Generated text summary saved to output_files\output_summary_122291061_Debie_B..txt
# Generated text summary saved to output_files\output_summary_694384897_Pietro_Catello.txt
# Generated text summary saved to output_files\output_summary_1009574587_Sean_Naderi.txt
# Generated text summary saved to output_files\output_summary_772121164_Jon_Lewen.txt
# Generated text summary saved to output_files\output_summary_938436673_Keiji_Ishibashi.txt
# Generated text summary saved to output_files\output_summary_132010158_Natia_Kiria_🇬🇪.txt
# Generated text summary saved to output_files\output_summary_996671814_Tony_mungai.txt
# Generated text summary saved to output_files\output_summary_109336075_Jeremy_Wolff.txt
# Generated text summary saved to output_files\output_summary_27743022_Rich_Sullivan.txt
# Generated text summary saved to output_files\output_summary_950950352_Amanda_Clark.txt
# Generated text summary saved to output_files\output_summary_907608058_Reece_Brown.txt
# Generated text summary saved to output_files\output_summary_833446107_Melanie_Keyzor.txt
# Generated text summary saved to output_files\output_summary_983485409_Pallet_Racking_Storage_Systems.txt
# Generated text summary saved to output_files\output_summary_976042735_Paul_Woodmansey.txt
# Generated text summary saved to output_files\output_summary_952826530_Jo_T..txt
# Generated text summary saved to output_files\output_summary_975344006_Rahul_Pushkarna.txt
# Generated text summary saved to output_files\output_summary_175688_Amir_Shevat.txt
# Generated text summary saved to output_files\output_summary_846312655_Akiko_Ikeda.txt
# Generated text summary saved to output_files\output_summary_122146239_Nagashankar_C..txt
# Generated text summary saved to output_files\output_summary_105136460_Rob_Lucas.txt
# Generated text summary saved to output_files\output_summary_774498641_Chris_Griner.txt
# Generated text summary saved to output_files\output_summary_760558846_Dennis_Lacanlale.txt
# Generated text summary saved to output_files\output_summary_836489774_Evangelos_Kokkinos.txt
# Generated text summary saved to output_files\output_summary_736535858_Suneesh_Madathil_Nair.txt
# Generated text summary saved to output_files\output_summary_121521298_Alexander_E..txt
# Generated text summary saved to output_files\output_summary_115815101_Rob_Schwartz.txt
# Generated text summary saved to output_files\output_summary_963148885_Miho_Sainoki.txt
# Generated text summary saved to output_files\output_summary_978079383_Liva_Cakule.txt
# Generated text summary saved to output_files\output_summary_983837162_Mattia_Lorenzo_Dililla.txt
# Generated text summary saved to output_files\output_summary_102192819_Talia_Ashley.txt
# Generated text summary saved to output_files\output_summary_56415530_Nicole_Stenhouse,_MSL.txt
# Generated text summary saved to output_files\output_summary_901690199_Hasan_Kurban.txt
# Generated text summary saved to output_files\output_summary_47209606_Olivia_Beach.txt
# Generated text summary saved to output_files\output_summary_1002809056_Eve_Mauboussin.txt
# Generated text summary saved to output_files\output_summary_765003646_Niamh_Barrett.txt
# Generated text summary saved to output_files\output_summary_785977573_Viraj_Patel.txt
# Generated text summary saved to output_files\output_summary_771447755_Andrew_Boczek.txt
# Generated text summary saved to output_files\output_summary_22311440_Patrick_Newman.txt
# Generated text summary saved to output_files\output_summary_110287902_Maureen_Lynch_Vogel.txt
# Generated text summary saved to output_files\output_summary_931532060_rajankumar_gupta.txt
# Generated text summary saved to output_files\output_summary_904547856_Marco_Wieck.txt
# Generated text summary saved to output_files\output_summary_1012871_Erin_Lang.txt
# Generated text summary saved to output_files\output_summary_74446298_Dante_Clemons.txt
# Generated text summary saved to output_files\output_summary_124312525_Shabazz_Farrakhan.txt
# Generated text summary saved to output_files\output_summary_84777899_oscar_utchay.txt
# Generated text summary saved to output_files\output_summary_57722305_David_Kirchner.txt
# Generated text summary saved to output_files\output_summary_768724664_David_Szendzielarz.txt
# Generated text summary saved to output_files\output_summary_113156130_Daniel_Lapidus.txt
# Generated text summary saved to output_files\output_summary_845966604_Nishita_Tibrewala.txt
# Generated text summary saved to output_files\output_summary_102768631_Rajesh_Bashetty.txt
# Generated text summary saved to output_files\output_summary_57502065_Lori_Tamarez.txt
# Generated text summary saved to output_files\output_summary_119529762_Nick_Vickroy.txt
# Generated text summary saved to output_files\output_summary_744357933_Dave_De_Haan.txt
# Generated text summary saved to output_files\output_summary_20602717_Brian_Kirrene.txt
# Generated text summary saved to output_files\output_summary_112571412_Greg_Zinsmeister.txt
# Generated text summary saved to output_files\output_summary_907276358_Javier_Gª_Pagán.txt
# Generated text summary saved to output_files\output_summary_39293249_Kenneth_Mowles.txt
# Generated text summary saved to output_files\output_summary_742633487_Amr_Aboelshawareb.txt
# Generated text summary saved to output_files\output_summary_757514_Alyson_Gausby.txt
# Generated text summary saved to output_files\output_summary_52989849_Sarah-Ann_Sullivan.txt
# Generated text summary saved to output_files\output_summary_121151043_Vanessa_Clarke_Young,_Esq.,_SPHR.txt
# Generated text summary saved to output_files\output_summary_22659320_Sean_Galligan.txt
# Generated text summary saved to output_files\output_summary_76996036_Julie_La.txt
# Generated text summary saved to output_files\output_summary_1008913076_Antonella_Biasi.txt
# Generated text summary saved to output_files\output_summary_848331148_Dalia_Seif.txt
# Generated text summary saved to output_files\output_summary_21292233_Hao_Tang.txt
# Generated text summary saved to output_files\output_summary_44655925_Dan_Henderson.txt
# Generated text summary saved to output_files\output_summary_845626681_Camila_Lacerda.txt
# Generated text summary saved to output_files\output_summary_122322061_Ripley_MacDonald.txt
# Generated text summary saved to output_files\output_summary_914521877_Derrick_Wong.txt
# Generated text summary saved to output_files\output_summary_893282661_Paco_Jimenez.txt
# Generated text summary saved to output_files\output_summary_892378044_Gabriela_Malta.txt
# Generated text summary saved to output_files\output_summary_87993295_Boone_Sommerfeld.txt
# Generated text summary saved to output_files\output_summary_1040966979_Monica_Reed.txt
# Generated text summary saved to output_files\output_summary_36184241_Park_Zilhaver.txt
# Generated text summary saved to output_files\output_summary_124423898_Betty_Prince.txt
# Generated text summary saved to output_files\output_summary_42753923_Sean_Watson.txt
# Generated text summary saved to output_files\output_summary_934355361_石橋憲人.txt
# Generated text summary saved to output_files\output_summary_53201664_Gloria_Creeger.txt
# Generated text summary saved to output_files\output_summary_870364069_Sarah_Kienitz.txt
# Generated text summary saved to output_files\output_summary_123080437_Gaberil_Ashford.txt
# Generated text summary saved to output_files\output_summary_46268995_Brian_Conover.txt
# Generated text summary saved to output_files\output_summary_716460359_Rene_SAnchez.txt
# Generated text summary saved to output_files\output_summary_44172531_Ferris_Derbidge.txt
# Generated text summary saved to output_files\output_summary_93588144_Zachary_Siegman.txt
# Generated text summary saved to output_files\output_summary_87452285_Steven_Feis.txt
# Generated text summary saved to output_files\output_summary_44453737_Alice_Hamilton.txt
# Generated text summary saved to output_files\output_summary_118009223_Joseph_Hayes.txt
# Generated text summary saved to output_files\output_summary_103276312_Diana_Peña.txt
# Generated text summary saved to output_files\output_summary_88341745_Easton_Craft.txt
# Generated text summary saved to output_files\output_summary_140868572_Grant_Coon.txt
# Generated text summary saved to output_files\output_summary_46364324_Lisa_Searing.txt
# Generated text summary saved to output_files\output_summary_87821070_Aniesh_Aravind.txt
# Generated text summary saved to output_files\output_summary_22368540_Stephanie_Palaganas.txt
# Generated text summary saved to output_files\output_summary_87484768_Vikash_Pansari.txt
# Generated text summary saved to output_files\output_summary_930214024_Richard_Coombes.txt
# Generated text summary saved to output_files\output_summary_51078886_Cathy_Hawk.txt
# Generated text summary saved to output_files\output_summary_122552986_Aurelio_Yrigoyen.txt
# Generated text summary saved to output_files\output_summary_87988921_Carlo_Bertucci.txt
# Generated text summary saved to output_files\output_summary_51069621_Barat_Smith.txt
# Generated text summary saved to output_files\output_summary_46363464_Lindsey_Garza.txt
# Generated text summary saved to output_files\output_summary_816159133_Saman_Mosaddegh.txt
# Generated text summary saved to output_files\output_summary_88079171_Daniel_Maxfield.txt
# Generated text summary saved to output_files\output_summary_46371075_Mark_Aycock.txt
# Generated text summary saved to output_files\output_summary_53240085_Kristen_Andrews.txt
# Generated text summary saved to output_files\output_summary_87909200_Bharath_Srinivasan.txt
# Generated text summary saved to output_files\output_summary_122857648_Victor_Weidman.txt
# Generated text summary saved to output_files\output_summary_30997453_April_Eubank.txt
# Generated text summary saved to output_files\output_summary_89733718_Mary_Pitek.txt
# Generated text summary saved to output_files\output_summary_35440239_Charles_Boswell.txt
# Generated text summary saved to output_files\output_summary_711823263_Patrick_Bamba.txt
# Generated text summary saved to output_files\output_summary_46420644_Steve_Chriss.txt
# Generated text summary saved to output_files\output_summary_770020157_Juan_De_Jesus_Palacios.txt
# Generated text summary saved to output_files\output_summary_896781624_Anna_Lee.txt
# Generated text summary saved to output_files\output_summary_715539726_Kuba_Krawczyk.txt
# Generated text summary saved to output_files\output_summary_46393383_Paul_Watts.txt
# Generated text summary saved to output_files\output_summary_931654218_Mauricio_Saravia_Aguiar.txt
# Generated text summary saved to output_files\output_summary_46325283_Jason_Simon.txt
# Generated text summary saved to output_files\output_summary_122215707_Warren_Townsend.txt
# Generated text summary saved to output_files\output_summary_694409203_Govind_Srinivasan.txt
# Generated text summary saved to output_files\output_summary_51190359_Kelly_Messman.txt
# Generated text summary saved to output_files\output_summary_122479076_Rebecca_Danner.txt
# Generated text summary saved to output_files\output_summary_103713801_Gwendolyn_Lawrence.txt
# Generated text summary saved to output_files\output_summary_108851932_Ethan_Kowert.txt
# Generated text summary saved to output_files\output_summary_46419120_Stan_Rankin.txt
# Generated text summary saved to output_files\output_summary_87849182_Arun_Chauhan.txt
# Generated text summary saved to output_files\output_summary_88481808_Jessica_Maus.txt
# Generated text summary saved to output_files\output_summary_36925707_Clayton_Dorris.txt
# Generated text summary saved to output_files\output_summary_834788547_Julian_Garibo.txt
# Generated text summary saved to output_files\output_summary_823551671_Joonseok_JK_Lee.txt
# Generated text summary saved to output_files\output_summary_1022934225_Norb_Schred.txt
# Generated text summary saved to output_files\output_summary_950282036_Walther_Keesling.txt
# Generated text summary saved to output_files\output_summary_1002945108_Marcelo_Puentes.txt
# Generated text summary saved to output_files\output_summary_930958490_Elisa_Saccani.txt
# Generated text summary saved to output_files\output_summary_46338293_Jonathan_Shoppach.txt
# Generated text summary saved to output_files\output_summary_46335103_Joe_Quinn.txt
# Generated text summary saved to output_files\output_summary_46279173_Cheryl_Lam.txt
# Generated text summary saved to output_files\output_summary_88268063_Denise_Soh_Buonerba.txt
# Generated text summary saved to output_files\output_summary_88359619_Elijah_Tymkiv.txt
# Generated text summary saved to output_files\output_summary_88260482_Erica_Hefnawy.txt
# Generated text summary saved to output_files\output_summary_46324237_Jaren_Gaddi.txt
# Generated text summary saved to output_files\output_summary_88951391_Kohl_Weir.txt
# Generated text summary saved to output_files\output_summary_111997794_Tami_Allen.txt
# Generated text summary saved to output_files\output_summary_1053410594_Lauren_Pisauro_(She_Her).txt
# Generated text summary saved to output_files\output_summary_123250116_Tina_Benson.txt
# Generated text summary saved to output_files\output_summary_124750159_Lee_Larson.txt
# Generated text summary saved to output_files\output_summary_95141984_Andres_Centellas.txt
# Generated text summary saved to output_files\output_summary_89125583_Penny_Mao,_PMP.txt
# Generated text summary saved to output_files\output_summary_22188702_Mark_Chiang.txt
# Generated text summary saved to output_files\output_summary_77234875_Macarena_Garcia_Simon.txt
# Generated text summary saved to output_files\output_summary_87839269_Annie_Crego.txt
# Generated text summary saved to output_files\output_summary_927925115_Jamie_Acutt.txt
# Generated text summary saved to output_files\output_summary_1049079183_Claire_H..txt
# Generated text summary saved to output_files\output_summary_54210860_Justin_Wallace.txt
# Generated text summary saved to output_files\output_summary_46291361_Dartt_Schoonmaker.txt
# Generated text summary saved to output_files\output_summary_88792029_Kari_Kiper.txt
# Generated text summary saved to output_files\output_summary_1082688135_Zabin_Sachedina.txt
# Generated text summary saved to output_files\output_summary_46334005_JoAnna_Pease.txt
# Generated text summary saved to output_files\output_summary_891000761_Shahin_Haghjou.txt
# Generated text summary saved to output_files\output_summary_29273615_Johnathan_Greer.txt
# Generated text summary saved to output_files\output_summary_122727906_Karen_Sinning.txt
# Generated text summary saved to output_files\output_summary_902147016_Lisa_Zhang.txt
# Generated text summary saved to output_files\output_summary_44645601_Don_Kleinosky.txt
# Generated text summary saved to output_files\output_summary_87597077_Tonya_DelMaestro.txt
# Generated text summary saved to output_files\output_summary_88200188_David_Law.txt
# Generated text summary saved to output_files\output_summary_88209405_David_Miller.txt
# Generated text summary saved to output_files\output_summary_124215727_Jenna_Harnish.txt
# Generated text summary saved to output_files\output_summary_46334690_Joe_Hendricks.txt
# Generated text summary saved to output_files\output_summary_937081806_Edgar_Estupinian.txt
# Generated text summary saved to output_files\output_summary_706070372_Lucas_Villanueva_Balcazar.txt
# Generated text summary saved to output_files\output_summary_92950021_Marianella_Morales.txt
# Generated text summary saved to output_files\output_summary_45081573_Pamala_Michael.txt
# Generated text summary saved to output_files\output_summary_122893170_Geetha_Jayaram.txt
# Generated text summary saved to output_files\output_summary_100042168_Daniel_Walts.txt
# Generated text summary saved to output_files\output_summary_103376180_Eric_B..txt
# Generated text summary saved to output_files\output_summary_88894976_Mark_Richards.txt
# Generated text summary saved to output_files\output_summary_124426668_Jennifer_E..txt
# Generated text summary saved to output_files\output_summary_935736394_Enrica_De_Colle.txt
# Generated text summary saved to output_files\output_summary_26023960_Julieta_Ramirez.txt
# Generated text summary saved to output_files\output_summary_46430813_Tom_Hill.txt
# Generated text summary saved to output_files\output_summary_1066646122_Opeyemi_Anifowose.txt
# Generated text summary saved to output_files\output_summary_121531758_Kimberly_Vassella.txt
# Generated text summary saved to output_files\output_summary_46345950_Karina_Santiago.txt
# Generated text summary saved to output_files\output_summary_122490840_Don_Fox.txt
# Generated text summary saved to output_files\output_summary_123607510_Jennifer_Baumhoer.txt
# Generated text summary saved to output_files\output_summary_47311755_George_Bethel.txt
# Generated text summary saved to output_files\output_summary_44521088_janya_banks.txt
# Generated text summary saved to output_files\output_summary_892661481_Romildo_de_Andrade_Barros.txt
# Generated text summary saved to output_files\output_summary_920446207_Sergio_Loyola.txt
# Generated text summary saved to output_files\output_summary_46327812_Jen_Enssle.txt
# Generated text summary saved to output_files\output_summary_46395039_Poornima_Majagi.txt
# Generated text summary saved to output_files\output_summary_52516316_Michael_Ladd.txt
# Generated text summary saved to output_files\output_summary_722316460_Aurelio_Lagarda_Fierro.txt
# Generated text summary saved to output_files\output_summary_100992649_Lance_Love.txt
# Generated text summary saved to output_files\output_summary_106321580_Blaize_LaFleur.txt
# Generated text summary saved to output_files\output_summary_46363945_Lisa_Estrada.txt
# Generated text summary saved to output_files\output_summary_119300471_Nicolle_Lafaurie.txt
# Generated text summary saved to output_files\output_summary_1373896_Chelsea_Kanduth.txt
# Generated text summary saved to output_files\output_summary_852411529_Jamie_Kirkpatrick.txt
# Generated text summary saved to output_files\output_summary_113180266_Daniel_Goodman.txt
# Generated text summary saved to output_files\output_summary_771435053_Ritik_Ahuja.txt
# Generated text summary saved to output_files\output_summary_772129748_Chris_Breeze.txt
# Generated text summary saved to output_files\output_summary_964131835_Elias_Raam.txt
# Generated text summary saved to output_files\output_summary_1056061600_Marianne_J._Mangels.txt
# Generated text summary saved to output_files\output_summary_26506014_Max_Werkmeister.txt
# Generated text summary saved to output_files\output_summary_833785051_Natasa_Soltic.txt
# Generated text summary saved to output_files\output_summary_22844026_Vahid_Pournavab.txt
# Generated text summary saved to output_files\output_summary_121183196_Zoë_Woehrmann.txt
# Generated text summary saved to output_files\output_summary_98752193_Pat_Mitchell.txt
# Generated text summary saved to output_files\output_summary_957739508_Susanna_Pelttari.txt
# Generated text summary saved to output_files\output_summary_698281954_Chris_Mulholland.txt
# Generated text summary saved to output_files\output_summary_118280901_Julia_Nicholls.txt
# Generated text summary saved to output_files\output_summary_111240239_Chantell_Rocha.txt
# Generated text summary saved to output_files\output_summary_162520477_Jonathan_Faulk.txt
# Generated text summary saved to output_files\output_summary_746050301_Anika_Chiaventone.txt
# Generated text summary saved to output_files\output_summary_113411805_Chelsea_LeSage.txt
# Generated text summary saved to output_files\output_summary_117268118_Marina_Moschitto.txt
# Generated text summary saved to output_files\output_summary_772456271_Jay_Cunanan.txt
# Generated text summary saved to output_files\output_summary_968596592_Rakesh_Shah.txt
# Generated text summary saved to output_files\output_summary_77787804_Charlotte_Nesbitt.txt
# Generated text summary saved to output_files\output_summary_984814916_marang_setshwaelo.txt
# Generated text summary saved to output_files\output_summary_120446344_Savanna_Rovira.txt
# Generated text summary saved to output_files\output_summary_845291255_Molly_Simon.txt
# Generated text summary saved to output_files\output_summary_1485494_Mark_Spicer.txt
# Generated text summary saved to output_files\output_summary_95981376_Christopher_Gomes.txt
# Generated text summary saved to output_files\output_summary_109545920_Jennifer_Buell.txt
# Generated text summary saved to output_files\output_summary_120861066_Teddy_Wenneker.txt
# Generated text summary saved to output_files\output_summary_24097480_Christopher_Demas.txt
# Generated text summary saved to output_files\output_summary_90683248_Anne_Cocos.txt
# Generated text summary saved to output_files\output_summary_46293160_David_Rogers.txt
# Generated text summary saved to output_files\output_summary_117951120_Jon_Widawsky.txt
# Generated text summary saved to output_files\output_summary_985508388_René_Ramírez.txt
# Generated text summary saved to output_files\output_summary_163290805_Sam_Thomas.txt
# Generated text summary saved to output_files\output_summary_124674845_Julie_CARLE.txt
# Generated text summary saved to output_files\output_summary_742653873_Alecsandra_Roman.txt
# Generated text summary saved to output_files\output_summary_994329606_taku_komaya.txt
# Generated text summary saved to output_files\output_summary_705050552_Géraldine_Igou.txt
# Generated text summary saved to output_files\output_summary_23912110_Carl_Chery.txt
# Generated text summary saved to output_files\output_summary_109885626_Laura_Dewing.txt
# Generated text summary saved to output_files\output_summary_119582742_Hyunjin_Park.txt
# Generated text summary saved to output_files\output_summary_761628392_Kossy_Ng.txt
# Generated text summary saved to output_files\output_summary_25035773_Gerard_Weber.txt
# Generated text summary saved to output_files\output_summary_948265491_Nick_Tay.txt
# Generated text summary saved to output_files\output_summary_691152531_Asutosh_Nayak.txt
# ...
# Generated text summary saved to output_files\output_summary_801125559_Paula_Christopher.txt
# Generated text summary saved to output_files\output_summary_123138298_Mike_Langberg.txt
# Generated text summary saved to output_files\output_summary_52694067_Hal_Higgins.txt
# Generated text summary saved to output_files\output_summary_124469_Razvan_Dinu.txt
# Generated text summary saved to output_files\output_summary_20156384_Premal_Savla.txt
# Generated text summary saved to output_files\output_summary_16417177_Shelly_Cerio.txt
# Generated text summary saved to output_files\output_summary_846638879_Tim_Murphy.txt
# Generated text summary saved to output_files\output_summary_905101836_Max_Schweinstetter.txt
# Generated text summary saved to output_files\output_summary_21538549_Howard_Wang.txt
# Generated text summary saved to output_files\output_summary_122802045_eddie_Guidry.txt
# Generated text summary saved to output_files\output_summary_875434910_Christian_Schneider.txt
# Generated text summary saved to output_files\output_summary_105559086_Renee_Pershall-Johnson.txt
# Generated text summary saved to output_files\output_summary_91570837_John_Smith.txt
# Generated text summary saved to output_files\output_summary_705907931_Kamdev_Kumar.txt
# Generated text summary saved to output_files\output_summary_752815566_Brian_Yang.txt
# Generated text summary saved to output_files\output_summary_20413290_Anurag_Chaudhary.txt
# Generated text summary saved to output_files\output_summary_124096080_Ting_Sun.txt
# Generated text summary saved to output_files\output_summary_21985248_Kevin_Schlichter.txt
# Generated text summary saved to output_files\output_summary_56832378_Ean_Mikale.txt
# Generated text summary saved to output_files\output_summary_20842798_Dave_Salvator.txt
# Generated text summary saved to output_files\output_summary_76603154_Cara_Hoefl.txt
# Generated text summary saved to output_files\output_summary_113093567_Edward_Ford.txt
# Generated text summary saved to output_files\output_summary_808297625_Eytan_Dreyfus.txt
# Generated text summary saved to output_files\output_summary_74131271_Soham_Desai.txt
# Generated text summary saved to output_files\output_summary_90950661_Colleen_McCloskey.txt
# Generated text summary saved to output_files\output_summary_22653120_Vatsala_Sreepad.txt
# Generated text summary saved to output_files\output_summary_16295708_Michal_Shoham.txt
# Generated text summary saved to output_files\output_summary_38387438_May_Casterline.txt
# Generated text summary saved to output_files\output_summary_22531996_Robert_Darby.txt
# Generated text summary saved to output_files\output_summary_20944655_Ray_Chu.txt
# Generated text summary saved to output_files\output_summary_15291733_Freddy_Salinas.txt
# Generated text summary saved to output_files\output_summary_16431761_Sheila_Albin.txt
# Generated text summary saved to output_files\output_summary_24300184_Daniel_Lindsey.txt
# Generated text summary saved to output_files\output_summary_61875681_Terry_Naas.txt
# Generated text summary saved to output_files\output_summary_95261451_Bill_Carrigan.txt
# Generated text summary saved to output_files\output_summary_94384185_Olivia_Anderson.txt
# Generated text summary saved to output_files\output_summary_66133627_Bryan_Hoffam.txt
# Generated text summary saved to output_files\output_summary_73559840_John_Charboneau.txt
# Generated text summary saved to output_files\output_summary_56538871_Cara_Lazure.txt
# Generated text summary saved to output_files\output_summary_715092570_Jane_King.txt
# Generated text summary saved to output_files\output_summary_16476187_David_Pinto.txt
# Generated text summary saved to output_files\output_summary_94602487_Ralph_Martignetti.txt
# Generated text summary saved to output_files\output_summary_124322883_Kris_(Meyer)_Panos.txt
# Generated text summary saved to output_files\output_summary_742979558_Emily_Wang.txt
# Generated text summary saved to output_files\output_summary_56682973_Jo_Rieck.txt
# Generated text summary saved to output_files\output_summary_742992466_Reco_Lin.txt
# Generated text summary saved to output_files\output_summary_115932692_Maryann_Coffas.txt
# Generated text summary saved to output_files\output_summary_886103347_Aha_Casastra.txt
# Generated text summary saved to output_files\output_summary_69650295_Adam_Augustine.txt
# Generated text summary saved to output_files\output_summary_1021422998_Iman_Mozaffari.txt
# Generated text summary saved to output_files\output_summary_109796082_Joshua_Limp.txt
# Generated text summary saved to output_files\output_summary_111916353_Roe_Kim.txt
# Generated text summary saved to output_files\output_summary_1040285706_James_Shirley.txt
# Generated text summary saved to output_files\output_summary_875779354_Johanna_Houben.txt
# Generated text summary saved to output_files\output_summary_702321191_Nicola_Burrows.txt
# Generated text summary saved to output_files\output_summary_47746781_Elliot_Bonilla.txt
# Generated text summary saved to output_files\output_summary_22565708_Tim_Wong.txt
# Generated text summary saved to output_files\output_summary_114871267_Henry_Chen.txt
# Generated text summary saved to output_files\output_summary_996701030_Lori_Clay.txt
# Generated text summary saved to output_files\output_summary_1053741782_Todd_V..txt
# Generated text summary saved to output_files\output_summary_972654387_Harri_Heikkilä.txt
# Generated text summary saved to output_files\output_summary_95529433_Christine_Duclos.txt
# Generated text summary saved to output_files\output_summary_64459969_Tina_Keller,_MBA,_PMP_with_Berkshire_Consulting.txt
# Generated text summary saved to output_files\output_summary_109788366_Laura_Haney.txt
# Generated text summary saved to output_files\output_summary_847317907_Andrew_Samuel.txt
# Generated text summary saved to output_files\output_summary_913024821_Maria_Guadalupe_Palestino_Herrera.txt
# Generated text summary saved to output_files\output_summary_1124247171_Kristina_Bartz.txt
# Generated text summary saved to output_files\output_summary_111419957_Dalia_Majumdar.txt
# Generated text summary saved to output_files\output_summary_1023792162_Monica_Lupi.txt
# Generated text summary saved to output_files\output_summary_61758045_Michael_Cooper,_Ph.D..txt
# Generated text summary saved to output_files\output_summary_813793941_Denise_de_la_Reza.txt
# Generated text summary saved to output_files\output_summary_109863921_Lan_Chen,_CFA.txt
# Generated text summary saved to output_files\output_summary_16276451_Linda_C..txt
# Generated text summary saved to output_files\output_summary_113332097_Charles_Caraballo.txt
# Generated text summary saved to output_files\output_summary_698949753_Arnab_Kundu.txt
# Generated text summary saved to output_files\output_summary_110857653_Michelle_Pike.txt
# Generated text summary saved to output_files\output_summary_119061695_Mohamed_Lotfy.txt
# Generated text summary saved to output_files\output_summary_124285790_Stacy_H_R..txt
# Generated text summary saved to output_files\output_summary_110407167_Michael_Burger.txt
# Generated text summary saved to output_files\output_summary_931660843_Liat_Grozovik.txt
# Generated text summary saved to output_files\output_summary_958425897_Graeme_Kerson.txt
# Generated text summary saved to output_files\output_summary_804278381_Beatriz_Llorente_Pérez.txt
# Generated text summary saved to output_files\output_summary_16506702_Vinod_Rex.txt
# Generated text summary saved to output_files\output_summary_16186778_Kalyan_Krishnamani.txt
# Generated text summary saved to output_files\output_summary_110026383_Liz_Reidel.txt
# Generated text summary saved to output_files\output_summary_110623725_Ana_Bedard,_PhD.txt
# Generated text summary saved to output_files\output_summary_111224408_Catherine_Terry.txt
# Generated text summary saved to output_files\output_summary_61642961_Kelly_Covert.txt
# Generated text summary saved to output_files\output_summary_16447992_Santanu_Dutta.txt
# Generated text summary saved to output_files\output_summary_711469731_Zeina_Chamli.txt
# Generated text summary saved to output_files\output_summary_110378190_Megha_Shah.txt
# Generated text summary saved to output_files\output_summary_123531609_Vijayakumar_Subbu.txt
# Generated text summary saved to output_files\output_summary_19853713_Mark_Bonfoey.txt
# Generated text summary saved to output_files\output_summary_988870966_Karen_Chong.txt
# Generated text summary saved to output_files\output_summary_697943639_Natalia_Price.txt
# Generated text summary saved to output_files\output_summary_991589757_Maria_Vasileva-Diehl.txt
# Generated text summary saved to output_files\output_summary_111149278_Naved_Siddiqui.txt
# Generated text summary saved to output_files\output_summary_1040823372_Anna_Singer,_MBA.txt
# Generated text summary saved to output_files\output_summary_87195503_C._Jean_Polmateer.txt
# Generated text summary saved to output_files\output_summary_110053002_Kimberly_Kwak.txt
# Generated text summary saved to output_files\output_summary_48460710_Elizabeth_Eyler-Pelletier.txt
# Generated text summary saved to output_files\output_summary_111032523_Brian_Steinberg.txt
# Generated text summary saved to output_files\output_summary_20212342_Rajeev_Bhatt.txt
# Generated text summary saved to output_files\output_summary_693168723_Zoe_Kimberley.txt
# Generated text summary saved to output_files\output_summary_22020471_Maryelise_Cieslewicz.txt
# Generated text summary saved to output_files\output_summary_95264626_Beatriz_Louzado.txt
# Generated text summary saved to output_files\output_summary_95020355_Tong_Yin.txt
# Generated text summary saved to output_files\output_summary_20124783_Piotr_Bialecki.txt
# Generated text summary saved to output_files\output_summary_15935711_Christophe_Le_Rouzo.txt
# Generated text summary saved to output_files\output_summary_69765614_Çağrı_Erbağcı.txt
# Generated text summary saved to output_files\output_summary_118450655_Tasha_Sims,_Ph.D..txt
# Generated text summary saved to output_files\output_summary_15884333_Bhavik_Patel.txt
# Generated text summary saved to output_files\output_summary_110274918_Marlon_Millhouse.txt
# Generated text summary saved to output_files\output_summary_23023897_Adam_Fleischer.txt
# Generated text summary saved to output_files\output_summary_985494097_Dr._Abd_El_Moniem_Abdelmonaem.txt
# Generated text summary saved to output_files\output_summary_109740677_Kentara_Mckinney.txt
# Generated text summary saved to output_files\output_summary_49371701_Jonathan_Stokes.txt
# Generated text summary saved to output_files\output_summary_64090788_Joel_Mau.txt
# Generated text summary saved to output_files\output_summary_825653126_Bimpe_Joseph.txt
# Generated text summary saved to output_files\output_summary_115246934_Arathi_Setty,_MD,_MPH.txt
# Generated text summary saved to output_files\output_summary_109163510_Jason_Dsilva.txt
# Generated text summary saved to output_files\output_summary_19975972_Nancy_Capelli.txt
# Generated text summary saved to output_files\output_summary_15563464_Mona_Cai.txt
# Generated text summary saved to output_files\output_summary_77798223_Chetasi_Talati.txt
# Generated text summary saved to output_files\output_summary_75141732_Steven_Grasley.txt
# Generated text summary saved to output_files\output_summary_54563719_Duane_Dial.txt
# Generated text summary saved to output_files\output_summary_108866524_Fred_Hortillosa.txt
# Generated text summary saved to output_files\output_summary_885929602_Vinayak_Pore.txt
# Generated text summary saved to output_files\output_summary_108901275_Jacqueline_Nielsen.txt
# Generated text summary saved to output_files\output_summary_111502535_Nancy_Coffman.txt
# Generated text summary saved to output_files\output_summary_783261759_Arancha_Martin_Romero.txt
# Generated text summary saved to output_files\output_summary_988131682_Judith_Wessels.txt
# Generated text summary saved to output_files\output_summary_939074038_Yoosook_Kim.txt
# Generated text summary saved to output_files\output_summary_111580676_David_Post.txt
# Generated text summary saved to output_files\output_summary_120845748_Tin_Le.txt
# Generated text summary saved to output_files\output_summary_23886989_Carolaine_Peroza.txt
# Generated text summary saved to output_files\output_summary_95610858_Christian_R._Schubert.txt
# Generated text summary saved to output_files\output_summary_1040114251_Albert_Evans,_MS.txt
# Generated text summary saved to output_files\output_summary_47612060_Michele_Cerra.txt
# Generated text summary saved to output_files\output_summary_123167242_Connie_Meyers.txt
# Generated text summary saved to output_files\output_summary_27992610_Sandy_Lane.txt
# Generated text summary saved to output_files\output_summary_111028894_Bruce_Barger.txt
# Generated text summary saved to output_files\output_summary_718569133_Gissel_Iniesta.txt
# Generated text summary saved to output_files\output_summary_111626684_Valerie_Niven.txt
# Generated text summary saved to output_files\output_summary_21984207_Kevin_Connors.txt
# Generated text summary saved to output_files\output_summary_109952008_Manish_Mittal.txt
# Generated text summary saved to output_files\output_summary_15111471_Jaime_Miller.txt
# Generated text summary saved to output_files\output_summary_51183773_Keenan_G..txt
# Generated text summary saved to output_files\output_summary_1484056_Lisa_Zepeda.txt
# Generated text summary saved to output_files\output_summary_111406411_Deb_Maki.txt
# Generated text summary saved to output_files\output_summary_1008896943_Rebecca_Webb.txt
# Generated text summary saved to output_files\output_summary_1934994_🤖_John-William_Trenholm.txt
# Generated text summary saved to output_files\output_summary_20533832_Bob_Pette.txt
# Generated text summary saved to output_files\output_summary_26838178_Ramanathan_Sundaram.txt
# Generated text summary saved to output_files\output_summary_123179092_Gregory_Brown.txt
# Generated text summary saved to output_files\output_summary_139667375_Yara_Khoury.txt
# Generated text summary saved to output_files\output_summary_104376302_Kevin_Lu.txt
# Generated text summary saved to output_files\output_summary_111875337_Sarah_Greene.txt
# Generated text summary saved to output_files\output_summary_111292476_Christina_Gabriel.txt
# Generated text summary saved to output_files\output_summary_111415515_Dana_Santos.txt
# Generated text summary saved to output_files\output_summary_67859616_Bruce_Dunn.txt
# Generated text summary saved to output_files\output_summary_118931031_Matt_Hayden.txt
# Generated text summary saved to output_files\output_summary_101255_RichardManoj__ShustermanPM.txt
# Generated text summary saved to output_files\output_summary_16549320_Vladimir_Troy.txt
# Generated text summary saved to output_files\output_summary_111794733_Rommy_Irawan.txt
# Generated text summary saved to output_files\output_summary_754645842_Seema_Khan.txt
# Generated text summary saved to output_files\output_summary_120276435_Sarah_Santos.txt
# Generated text summary saved to output_files\output_summary_715895815_Patrick_Horber.txt
# Generated text summary saved to output_files\output_summary_15859802_Anitha_Pai.txt
# Generated text summary saved to output_files\output_summary_116711022_Stephen_Mackenzie.txt
# Generated text summary saved to output_files\output_summary_1051190958_Finley_Cox.txt
# Generated text summary saved to output_files\output_summary_21324503_Cobit_Gurpreet_Singh.txt
# Generated text summary saved to output_files\output_summary_791102359_Frank_Oellien.txt
# Generated text summary saved to output_files\output_summary_43351401_Vincent_Hos.txt
# Generated text summary saved to output_files\output_summary_149312_Shawn_Rider.txt
# Generated text summary saved to output_files\output_summary_756197589_Tomas_Akenine-Möller.txt
# Generated text summary saved to output_files\output_summary_122195532_Jeanine_Dorn.txt
# Generated text summary saved to output_files\output_summary_742299193_Stephen_O_Donnell.txt
# Generated text summary saved to output_files\output_summary_995009386_Karine_DESCHET.txt
# Generated text summary saved to output_files\output_summary_793417200_Veanndra_Ellis.txt
# Generated text summary saved to output_files\output_summary_56622026_Erin_Nopp.txt
